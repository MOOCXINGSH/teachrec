# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

f500 = pd.read_csv("wkreport.csv", encoding = 'utf8',index_col=0)
print(f500.head(10))
print(f500.tail(10))
print(f500.info())

weeksch=np.zeros([5,7])

dr=pd.date_range("2018-01-01 0:0", periods=5,freq="30min")
#print(dr)
strtime=[]
empty=[]
for date in dr:
    strtime.append(str(date)[11:16])
    empty.append("  ")
print(date.dayofweek)

weekdef=["周一","周二","周三","周四","周五","周六","周日"]
df=pd.DataFrame(weeksch,columns=weekdef)

for wk in weekdef:
    df[wk]=empty
#df["时间"]=strtime

dr=pd.date_range("2018-06-01","2018-06-30",freq="D")
line=0
for date in dr:
    strdate=str(date)[0:10]
    dayofweek=date.dayofweek
    print(strdate,dayofweek)
    todaywkrec=f500[f500["Workdate"]==strdate]
    if not todaywkrec.empty:
        teachers=todaywkrec["Teacher"]
        teacherstr=""
        for teacher in teachers:
            teacherstr+=" "+str(teacher)
        teacherstr+="|"
        wkmaps=todaywkrec["WkRecMap"]
        for wkmap in wkmaps:
            students=str(wkmap).split("|")[1]
            teacherstr+=students
        df.loc[line,weekdef[dayofweek]]=teacherstr
        
    else:
        df.loc[line,weekdef[dayofweek]]=strdate[5:10]
    if dayofweek==6:
        line+=1
print(df)
# Out:
#      Workdate Teacher  WorkHours  \
# 0  2018-06-02     阮煜东        2.5
# 1  2018-06-02     周克彦        4.5
# 2  2018-06-02     谢凯年        6.0
# 3  2018-06-02     李文峰        5.0
# 4  2018-06-03     周克彦        2.5
# 5  2018-06-03     谢凯年        2.5
# 6  2018-06-06     谢凯年        2.5
# 7  2018-06-09     阮煜东        2.5
# 8  2018-06-09     周克彦        4.5
# 9  2018-06-09     谢凯年        6.0
#
#                                             WkRecMap
# 0  00010203040506070809101112131TTTTT171819202122...
# 1  00010203040506070809101112TTTTTTTTT71819202122...
# 2  00010203040506070809101112131TTTTTTTTTTTT02122...
# 3  0001020304050607080TTTTT12131415TTTTT819202122...
# 4  0001020304050607080TTTTT1213141516171819202122...
# 5  000102030405060708091011121314151TTTTT19202122...
# 6  000102030405060708091011121TTTTT16171819202122...
# 7  00010203040506070809101112131TTTTT171819202122...
# 8  00010203040506070809101112TTTTTTTTT71819202122...
# 9  00010203040506070809101112131TTTTTTTTTTTT02122...
#       Workdate Teacher  WorkHours  \
# 18  2018-06-19     谢凯年        7.5
# 19  2018-06-20     杨佳庆        7.5
# 20  2018-06-23     阮煜东        2.0
# 21  2018-06-23     杨佳庆        2.5
# 22  2018-06-23     谢凯年        2.5
# 23  2018-06-24     谢凯年        4.5
# 24  2018-06-28     李文峰        2.5
# 25  2018-06-30     阮煜东        2.0
# 26  2018-06-30     杨佳庆        2.5
# 27  2018-06-30     谢凯年        4.5
#
#                                              WkRecMap
# 18  000102030405060708TTTTTTTTTTTTTTT6171819202122...
# 19  000102030405060708TTTTTTTTTTTTTTT6171819202122...
# 20  000102030405060708091011121314151TTTT819202122...
# 21  0001020304050607080910111213TTTTT6171819202122...
# 22  0001020304050607080910111213141516TTTTT9202122...
# 23  00010203040506070809101112131TTTTTTTTT19202122...
# 24  TTTTT20304050607080910111213141516171819202122...
# 25  000102030405060708091011121314151TTTT819202122...
# 26  00010203040506070809101112TTTTT516171819202122...
# 27  00010203040506070809101112131TTTTTTTTT19202122...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28 entries, 0 to 27
# Data columns (total 4 columns):
# Workdate     28 non-null object
# Teacher      28 non-null object
# WorkHours    28 non-null float64
# WkRecMap     28 non-null object
# dtypes: float64(1), object(3)
# memory usage: 1.1+ KB
# None
# 0
# 2018-06-01 4
# 2018-06-02 5
# 2018-06-03 6
# 2018-06-04 0
# 2018-06-05 1
# 2018-06-06 2
# 2018-06-07 3
# 2018-06-08 4
# 2018-06-09 5
# 2018-06-10 6
# 2018-06-11 0
# 2018-06-12 1
# 2018-06-13 2
# 2018-06-14 3
# 2018-06-15 4
# 2018-06-16 5
# 2018-06-17 6
# 2018-06-18 0
# 2018-06-19 1
# 2018-06-20 2
# 2018-06-21 3
# 2018-06-22 4
# 2018-06-23 5
# 2018-06-24 6
# 2018-06-25 0
# 2018-06-26 1
# 2018-06-27 2
# 2018-06-28 3
# 2018-06-29 4
# 2018-06-30 5
#           周一         周二         周三             周四     周五  \
# 0                                                  06-01
# 1      06-04      06-05   谢凯年|邱淑君           06-07  06-08
# 2      06-11      06-12      06-13          06-14  06-15
# 3   谢凯年|张羽捷    谢凯年|张羽捷    杨佳庆|张羽捷           06-21  06-22
# 4      06-25      06-26      06-27   李文峰|吴道文 冯紫瑜   06-29
#
#                                                   周六  \
# 0       阮煜东 周克彦 谢凯年 李文峰|茅轩铭 茅轩铭 吴怡婷 朱凯文 林长昊 冯紫瑜 吴道文
# 1   阮煜东 周克彦 谢凯年 李文峰|钟鹰一 茅轩铭 吴怡婷 吴怡婷 朱凯文 林长昊 冯紫瑜 吴道文
# 2                               谢凯年 李文峰|朱凯文 张羽捷 吴道文
# 3                         阮煜东 杨佳庆 谢凯年|茅轩铭 黄璨 谢尚 林长昊
# 4                 阮煜东 杨佳庆 谢凯年|茅轩铭 黄璨 谢尚 朱凯文 陈玺诺 蔡霄汉
#
#                               周日
# 0           周克彦 谢凯年|姚诗怡 许岂伟 王子寅
# 1   周克彦 谢凯年|姚诗怡 赵昱旻 许岂伟 杨连羽 王子寅
# 2       阮煜东 谢凯年|茅轩铭 张羽捷 杨连羽 王子寅
# 3           谢凯年|蔡霄汉 许岂伟 杨连羽 王子寅
# 4

# %% [markdown]
# # 写入excel文件

# %%
df.to_csv("monthlywkreport.csv",encoding="utf_8_sig")
